# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ***Q-1.Load data in Python on Jupyter notebook***

# %%
df = pd.read_csv("Titanic.csv", encoding = 'latin1')
df.sort_index()
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ***Q-2.Print starting 10 rows and last 10 rows***

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
df.tail(10)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 881          882         0       3                        Markun, Mr. Johann
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %% [markdown]
# ***Q-3.What is the shape of the Data ?***

# %%
df.shape
# Out:
# (891, 12)

# %% [markdown]
# ***Q-4.Print the names of all the columns***

# %%
df.columns.tolist()
# Out:
# ['PassengerId',
#  'Survived',
#  'Pclass',
#  'Name',
#  'Sex',
#  'Age',
#  'SibSp',
#  'Parch',
#  'Ticket',
#  'Fare',
#  'Cabin',
#  'Embarked']

# %% [markdown]
# ***Q-5.Find the Datatypes of the columns***

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# ***Q-6.Print Information and Describe the Data***

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# ***Q-7.Count Survived and show on pie chart***

# %%
cs = df['Survived'].value_counts()
cs
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6,6))
plt.pie(x = cs, labels = ['Dead', 'Survived'], autopct= '%1.2f%%', shadow = True, startangle= 90, explode= (0,0.1), 
        wedgeprops={'edgecolor': 'black', 'linewidth': 2}, textprops= {'fontweight': 'bold', 'fontsize': 14, 'rotation': -45},
        pctdistance= 0.7, colors = ['lightblue', 'lightgreen'])
plt.title('Survival Count by Percentage', fontweight = 'bold', fontsize = 18);

# %% [markdown]
# ***Q-8.Find out how many female passengers had travelled in first class and show on pie chart***

# %%
mask1 = df['Sex'] == 'female'

# %%
female_data = df[mask1]

# %%
fc1 = female_data['Pclass'].value_counts()
fc1
# Out:
# Pclass
# 3    144
# 1     94
# 2     76
# Name: count, dtype: int64

# %%
plt.figure(figsize=(7,7))
plt.pie(x = fc1, labels = ['3rd Class','1st Class','2nd Class'], shadow = True, explode = (0,0.1,0), startangle = 90, autopct = '%1.2f%%', colors = ['skyblue','yellow','pink'],
        wedgeprops = {'edgecolor' : 'black', 'linewidth' : 2}, textprops = {'fontweight' : 'bold', 'fontstyle' : 'italic', 'fontsize' : '12'})
plt.title('Ticket Class of Female Passengers (in %age)', fontsize = 16, fontweight = 'bold');

# %% [markdown]
# ***Q-9.Find out how many female passengers had survived and her age < 30 , show on pie chart and bar graph***

# %%
mask2 = female_data['Age'] < 30
FSA = female_data[mask2]
SA = FSA['Survived'].value_counts()
SA2 = FSA.groupby(['Survived'], as_index = False)['Age'].count()

# %%
plt.pie(x = SA, labels = ['Survived', 'Dead'], autopct= '%1.2f%%', shadow = True, startangle= 90, explode= (0,0.1), 
        wedgeprops={'edgecolor': 'black', 'linewidth': 2}, textprops= {'fontweight': 'bold', 'fontsize': 14},
        pctdistance= 0.7, colors = ['lightblue', 'lightgreen'])
plt.title('Female Younger than 30 yrs Survival (in %age)', fontweight = 'bold', fontsize = 18);

# %%
from matplotlib.font_manager import FontProperties

# %%
plt.figure(figsize=(5,7))
br1 = sns.barplot(x = 'Survived', y = 'Age', data = SA2, hue = 'Survived', zorder = 2)

for i in br1.containers:
    br1.bar_label(i, label_type = 'center', fontweight = 'bold', fontsize = 12)

plt.xlabel('Survival', fontsize = 12, fontweight = 'bold')
plt.ylabel('Count', fontweight = 'bold', fontsize = 12)
plt.xticks(ticks = [0,1], labels = ['Dead', 'Survived'], fontweight = 'bold')
plt.yticks(fontweight = 'bold')
handles, labels = br1.get_legend_handles_labels()
plt.legend(handles = handles, labels = ['Dead', 'Survided'], title ='Survival',
           prop = {'weight': 'bold'}, title_fontproperties = FontProperties(weight='bold'))
plt.grid(color = 'white', axis = 'y', zorder = 1, linewidth = 4)
plt.gca().set_facecolor(color = 'lightgrey')
plt.title('Female Younger than 30 yrs Survival', fontweight = 'bold', fontsize = 16, pad = 15)
br1.spines['left'].set_visible(False)
br1.spines['right'].set_visible(False)
br1.spines['top'].set_visible(False)
br1.tick_params(axis='y', length=0)

# %% [markdown]
# ***Q-10.Find out how many Male passengers had survived and his age > 40, show on pie chart and bar graph.***

# %%
mask3 = df[(df['Sex'] == 'male') & (df['Age'] > 40)]
msp = mask3.groupby(['Survived'], as_index = False)['Survived'].count()

# %%
plt.figure(figsize = (6,6))
plt.pie(x = msp['Survived'], labels = ['Dead', 'Survived'], autopct= '%1.1f%%',shadow = True, explode = (0,0.1),startangle= 90, 
        wedgeprops= {'edgecolor': 'black', 'linewidth': 2}, textprops= {"fontweight": 'bold', 'fontsize': 12}, colors = ['orange','lightgreen'])
plt.title('Survival of Male Passsengers above age 40 yrs', fontsize = 18, fontweight = 'bold');

# %%
plt.figure(figsize=(5,7))
ms = sns.barplot(x = msp.index, y = 'Survived', data = msp, hue = msp.index, zorder = 2)

for i in ms.containers:
    ms.bar_label(i, fontweight = 'bold')

handles = ms.get_legend_handles_labels()[0]
plt.legend(title = 'Survival', labels = ['Dead', 'Survived'], handles = handles, prop = {'weight': 'bold'}, title_fontproperties=FontProperties(weight = 'bold'))
plt.xlabel('Survival', fontweight = 'bold', fontsize = 12)
plt.ylabel('Count of Passengers', fontweight = 'bold', fontsize = 12)
plt.xticks(ticks = [0,1], labels = ['Dead', 'Survived'], fontweight = 'bold')
plt.yticks(fontweight = 'bold')
plt.grid(axis = 'y', color = 'white', linewidth = 3, zorder = 1)
plt.gca().spines[['left', 'top', 'right']].set_visible(False)
plt.gca().set_facecolor('lightgrey')
plt.title('Survival of Male Passengers above age 40 yrs', fontweight = 'bold', fontsize = 15, pad = 15);

# %% [markdown]
# ***Q-11.Show age with 20 bins***

# %%
plt.figure(figsize = (12,6))
age_data = df["Age"].dropna()

counts, bins = np.histogram(age_data, bins=20)   # Compute histogram bin counts manually
bin_centers = (bins[:-1] + bins[1:]) / 2

ax = sns.histplot(age_data, bins=20, kde=False, color = 'yellow', edgecolor = 'red', label = 'Hist', zorder = 2, alpha = 1)

plt.plot(bin_centers, counts, marker='o', linestyle='-', color='r', label='Age Distribution')

plt.title("Age Distribution of Titanic Passengers", fontsize = 16, fontweight = 'bold')
plt.xlabel("Age", fontweight='bold', fontsize=12)
plt.ylabel("Frequency in Count", fontweight='bold', fontsize=12)
plt.xticks(np.arange(0,84,4))
plt.grid(axis = 'y', color = 'white', linewidth = 3, zorder = 1)
plt.gca().spines[['left', 'top', 'right']].set_visible(False)
plt.gca().set_facecolor('lightgrey')
plt.tick_params(axis='both', length=0)
plt.legend();

# %% [markdown]
# ***Q-12.Show age frequency with survived and not survived (Histogram)***

# %%
plt.figure(figsize=(10,6))

# Histogram with hue based on survival
ad = sns.histplot(data=df, x="Age", hue="Survived", multiple="dodge", palette="Set1", edgecolor='black',zorder = 2,alpha = 1)

for i in ad.containers:
    ad.bar_label(i, fmt='%d', fontsize=9, color='black', padding = 4)

# Survived group
age_survived = df[df["Survived"] == 1]["Age"]
counts_s, _ = np.histogram(age_survived, bins=bins)
bin_centers = (bins[:-1] + bins[1:]) / 2 +1
plt.plot(bin_centers, counts_s, color='red', marker='o', linestyle='-', label='Survived (Line)', zorder=3)

# Not Survived group
age_notsurvived = df[df["Survived"] == 0]["Age"]
counts_ns, _ = np.histogram(age_notsurvived, bins=bins)
bin_centers2 = (bins[:-1] + bins[1:]) / 2 -1
plt.plot(bin_centers2, counts_ns, color='blue', marker='s', linestyle='--', label='Not Survived (Line)', zorder=3)

# Customize plot
plt.title("Age Distribution by Survival Status", fontsize=16, fontweight='bold')
plt.xlabel("Age", fontsize=12, fontweight='bold')
plt.ylabel("Frequency", fontsize=12, fontweight='bold')
plt.xticks(np.arange(0,84,4))
plt.legend(title="Survived", labels=["No", "Yes"])
plt.grid(axis='y', linestyle='--', zorder = 1)
plt.tick_params(axis='both', length=0)
plt.tight_layout();

# %%
ahs = df[df['Survived'] == 1]
ahns = df[df['Survived'] == 0]
pcc = ahs['Pclass'].value_counts().index
pcc
# Out:
# Index([1, 3, 2], dtype='int64', name='Pclass')

# %%
plt.figure(figsize=(12,5))
svd = sns.histplot(data = ahs, x = 'Age', bins = 20, color = 'yellow', edgecolor = 'red', label = 'Hist')

for i in svd.containers:
    svd.bar_label(i, padding = 10)

bx = plt.gca()
counts = [patch.get_height() for patch in bx.patches]
bin_centers = [patch.get_x() + patch.get_width()/2 for patch in bx.patches]
plt.plot(bin_centers, counts, color = 'red', marker = 'o', label = "Age Distribution")
plt.title('Age distribution of passengers who Survived', fontsize = 16, fontweight = 'bold', pad = 20)
plt.xticks(np.arange(0,81,4))
plt.yticks(np.arange(0,46,5))
plt.xlabel('Age', fontsize = 12, fontweight = 'bold')
plt.ylabel('Frequency', fontweight = 'bold' , fontsize = 12)
plt.legend(prop = {'weight': 'bold'})

# %%
plt.figure(figsize=(12,5))
nsvd = sns.histplot(data = ahns, x = 'Age', bins = 20, color = 'yellow', edgecolor = 'red', label = 'Hist')

for i in nsvd.containers:
    nsvd.bar_label(i, padding = 10)

dx = plt.gca()
counts = [patch.get_height() for patch in dx.patches]
bin_centers = [patch.get_x() + patch.get_width()/2 for patch in dx.patches]
plt.plot(bin_centers, counts, color = 'red', marker = 'o', label = "Age Distribution")
plt.title('Age distribution of passengers who Not Survived', fontsize = 16, fontweight = 'bold', pad = 20)
plt.xticks(np.arange(1,75,4))
plt.yticks(np.arange(0,66,5))
plt.xlabel('Age', fontsize = 12, fontweight = 'bold')
plt.ylabel('Frequency', fontweight = 'bold' , fontsize = 12)
plt.legend(prop = {'weight': 'bold'});

# %% [markdown]
# ***Q-13.Show Bar graph for Survived Passengers with Sex and Class***

# %%
ssc = ahs.groupby(['Pclass', 'Sex'], as_index = False)['Survived'].count()

# %%
sc1 = sns.barplot(data = ssc, x = 'Pclass', y = 'Survived', hue = 'Sex', zorder= 2)

for i in sc1.containers:
    sc1.bar_label(i, fontweight = 'bold')

plt.title('Class of Male and Female passengers who Survived', fontweight = 'bold', fontsize = 16)
plt.gca().set_facecolor('lightgrey')
plt.tick_params(length = 0)
plt.gca().spines[['left','right', 'top']].set_visible(False)
plt.grid(axis ='y', color = 'white', linewidth = 2.5, zorder = 1)
plt.xticks([0,1,2], ['1st Class', '2nd Class', '3rd Class'], fontweight = 'bold')
plt.yticks(np.arange(0,101,20), fontweight = 'bold')
plt.xlabel('Class of Passengers', fontsize = 12, fontweight = 'bold')
plt.ylabel('Count of Passengers', fontweight = 'bold', fontsize = 12);

# %% [markdown]
# ***Q-14.How many passangers are travelled in different calsses show in Bar graph***

# %%
cpc = sns.countplot(x = 'Pclass', data = df, hue = 'Pclass', palette= 'deep', zorder = 2, order = (3,1,2))

for i in cpc.containers:
    cpc.bar_label(i, fontweight = 'bold')

plt.title('Count of Passengers Travelled in Different Classes', fontweight = 'bold', fontsize = 16, pad = 20)
plt.xticks([0,1,2], ['3rd Class', '1st Class', '2nd Class'], fontweight = 'bold')
plt.xlabel('Class of Passengers', fontweight = 'bold', fontsize = 12)
plt.ylabel('Count of Passengers', fontweight = 'bold', fontsize = 12)
plt.gca().set_facecolor('lightgrey')
plt.gca().spines[['left','right','top']].set_visible(False)
plt.tick_params(length = 0)
plt.grid(axis = 'y', color = 'white', linewidth = 3, zorder = 1)

# %% [markdown]
# ***Q-15.How many passengers are survived in different class, show in Bar graph***

# %%
sdc = sns.countplot(data = df, x = 'Pclass', hue = 'Survived', palette = 'deep', zorder = 2, order = pcc)

for i in sdc.containers:
    sdc.bar_label(i, padding= 2)

plt.title('Class of Passengers by Survival', fontweight = 'bold', fontsize = 16, pad = 20)
plt.gca().set_facecolor('lightgrey')
plt.grid(axis = 'y', color = 'white', linewidth = 3, zorder = 1)
plt.gca().spines[['left','right','top']].set_visible(False)
plt.tick_params(length = 0)
plt.xticks([0,1,2], ['1st Class', '3rd Class', '2nd Class'], fontweight = 'bold')
plt.xlabel('Class of Passengers', fontweight = 'bold', fontsize = 12)
plt.ylabel('Count of Passengers', fontweight = 'bold', fontsize = 12)
plt.legend(labels = ['Dead', 'Survived'])

# %% [markdown]
# ***Q-16.Show Question-13 & Question-14 in subplot***

# %%
fig, axs = plt.subplots(1,2, figsize = (12,6))

sc1 = sns.barplot(data = ssc, x = 'Pclass', y = 'Survived', hue = 'Sex', zorder= 2, ax = axs[0])

fig.suptitle('Question 13 and Questuin 14', fontsize = 16, fontweight = 'bold')

for i in sc1.containers:
    sc1.bar_label(i, fontweight = 'bold')

axs[0].set_title('Class of Male and Female passengers who Survived', fontweight = 'bold', fontsize = 12, pad = 20)
axs[0].set_facecolor('lightgrey')
axs[0].tick_params(length = 0)
axs[0].spines[['left','right', 'top']].set_visible(False)
axs[0].grid(axis ='y', color = 'white', linewidth = 2.5, zorder = 1)
axs[0].set_xticks([0,1,2], ['1st Class', '2nd Class', '3rd Class'], fontweight = 'bold')
axs[0].set_yticks(np.arange(0,101,20))
axs[0].set_xlabel('Class of Passengers', fontsize = 12, fontweight = 'bold')
axs[0].set_ylabel('Count of Passengers', fontweight = 'bold', fontsize = 12);


cpc = sns.countplot(x = 'Pclass', data = df, hue = 'Pclass', palette= 'deep', zorder = 2, order = (3,1,2), ax = axs[1])

for i in cpc.containers:
    cpc.bar_label(i, fontweight = 'bold')

axs[1].set_title('Count of Passengers Travelled in Different Classes', fontweight = 'bold', fontsize = 12, pad = 20)
axs[1].set_xticks([0,1,2], ['3rd Class', '1st Class', '2nd Class'], fontweight = 'bold')
axs[1].set_xlabel('Class of Passengers', fontweight = 'bold', fontsize = 12)
axs[1].set_ylabel('Count of Passengers', fontweight = 'bold', fontsize = 12)
axs[1].set_facecolor('lightgrey')
axs[1].spines[['left','right','top']].set_visible(False)
axs[1].tick_params(length = 0)
axs[1].grid(axis = 'y', color = 'white', linewidth = 3, zorder = 1)
fig.tight_layout()

# %% [markdown]
# ***Q-17.Show Bar graph for Survived with 3rd class male, 1st class female***

# %%
q171 = pd.DataFrame(df[(df.Pclass == 3) & (df.Sex == 'male')].Survived.value_counts())
q171
# Out:
#           count
# Survived
# 0           300
# 1            47

# %%
q172 = pd.DataFrame(df[(df.Pclass == 1) & (df.Sex == 'female')].Survived.value_counts())
q172
# Out:
#           count
# Survived
# 1            91
# 0             3

# %%
fig, axs = plt.subplots(1,2,figsize = (12,6))

Q181 = sns.barplot(data = q171, y = 'count', x = q171.index, hue = q171.index, palette = ['red','green'], ax = axs[0], zorder = 2)

for i in Q181.containers:
    Q181.bar_label(i,fontweight = 'bold')

axs[0].set_title('Survival count of Male in 3rd Class', fontweight = 'bold', fontsize = 12, pad = 15)
axs[0].set_xticks([0,1], ['Dead','Survived'], fontweight = 'bold')
axs[0].set_xlabel('Survival', fontweight = 'bold', fontsize = 12)
axs[0].set_ylabel('Passenger Count', fontweight = 'bold', fontsize = 12)
axs[0].set_yticks(np.arange(0,350,50))
axs[0].grid(axis = 'y', linewidth = 3, color = 'white', zorder = 1)
axs[0].set_facecolor('lightgrey')
handles1 = axs[0].get_legend_handles_labels()[0]
axs[0].legend(labels = ['Dead', 'Survived'], handles = handles1)


Q182 = sns.barplot(data = q172, x = q172.index,y = 'count', hue = q172.index, palette = ['red','green'], ax = axs[1], zorder = 2, order = (1,0))

for i in Q182.containers:
    Q182.bar_label(i, fontweight = 'bold')

axs[1].set_title('Survival count of Female in 1st Class', fontweight = 'bold', fontsize = 12, pad = 15)
axs[1].set_xticks([0,1], ['Survived', 'Dead'], fontweight = 'bold')
axs[1].set_xlabel('Survival', fontweight = 'bold', fontsize = 12)
axs[1].set_ylabel('Passenger Count', fontweight = 'bold', fontsize = 12)
axs[1].set_yticks(np.arange(0,100,10))
axs[1].grid(axis = 'y', linewidth = 3, color = 'white', zorder = 1)
axs[1].set_facecolor('lightgrey')
handles2 = axs[1].get_legend_handles_labels()[0]
axs[1].legend(labels = ['Dead','Survived'], handles = handles2)

fig.suptitle('Survival of Males in 3rd Class and Females in 1st Class', fontweight = 'bold', fontsize = 14)
fig.tight_layout()

# %% [markdown]
# ***Q-18.How many 1st class Female passengers are survived / not survived ?***

# %%
PPP = pd.crosstab(female_data['Survived'], df['Pclass'], margins = True)
PPP = PPP.rename(index={0: 'Dead', 1: 'Survived'})
PPP.index.name = 'Survival of 1st Class Female Passengers'
PPP[1]
# Out:
# Survival of 1st Class Female Passengers
# Dead         3
# Survived    91
# All         94
# Name: 1, dtype: int64

# %% [markdown]
# ***Q-19.Map the Sex column male = 1, female = 0***

# %%
# df.Sex = df.Sex.map({'male': 1, 'female': 0})
df.Sex
# Out:
# 0      1
# 1      0
# 2      0
# 3      0
# 4      1
#       ..
# 886    1
# 887    0
# 888    0
# 889    1
# 890    1
# Name: Sex, Length: 891, dtype: int64

# %% [markdown]
# ***Q-20.Find Null values***

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# ***Q-21.Replace Null value to Median value***

# %%
# df.Age.isnull().sum()
# df['Age'] = df['Age'].fillna(df.Age.median())
df['Age'].isnull().sum()
# Out:
# np.int64(0)

# %%
df.loc[[885,888,890],'Age']
# Out:
# 885    39.0
# 888    28.0
# 890    32.0
# Name: Age, dtype: float64

# %% [markdown]
# ***Q-22.Drop unwanted columns***

# %%
df.drop(columns= ['PassengerId', 'Name', 'Cabin', 'Ticket', 'Fare', 'Embarked'], inplace = True)

# %%
df
# Out:
#      Survived  Pclass  Sex   Age  SibSp  Parch
# 0           0       3    1  22.0      1      0
# 1           1       1    0  38.0      1      0
# 2           1       3    0  26.0      0      0
# 3           1       1    0  35.0      1      0
# 4           0       3    1  35.0      0      0
# ..        ...     ...  ...   ...    ...    ...
# 886         0       2    1  27.0      0      0
# 887         1       1    0  19.0      0      0
# 888         0       3    0  28.0      1      2
# 889         1       1    1  26.0      0      0
# 890         0       3    1  32.0      0      0
#
# [891 rows x 6 columns]
